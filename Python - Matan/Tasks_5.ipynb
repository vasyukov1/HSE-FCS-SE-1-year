# %% [markdown]
# ## Практическое занятие 5
# ## Математический анализ
# ## Численное решение нелинейных уравнений: nsolve
# https://docs.sympy.org/latest/modules/solvers/solvers.html?highlight=nsolve#sympy.solvers.solvers.nsolve
#
# #### Уравнение в форме $f(x)=0$

# %%
import numpy as np
import sympy
from sympy import nsolve
import matplotlib.pyplot as plt
from IPython.display import display, Latex
# %matplotlib inline

# %% [markdown]
# ### Задача 1
# Решить уравнение $𝑥^4−e^x=0$ при $-2 \le x \le 2$, построить график левой части, отметить точки пересечения с осью ОХ.

# %%
def f(x, lib = 'sympy'):
  if lib == 'sympy':
    return x**4 - sympy.exp(x)
  if lib == 'numpy':
    return x**4 - np.exp(x)
  return 'Клоун, пиши нормально!'

x = sympy.Symbol('x')
X = np.linspace(-2, 2)

roots = [sympy.nsolve(sympy.Eq(f(x, lib='sympy'), 0), x, x0) for x0 in [-2, 2]]
display(Latex(f'\\text{{Корни уравнения: }}{sympy.latex(roots)}'))

ax = plt.gca()
ax.plot(X, f(X, lib='numpy'), color='pink')
y_coord = [f(float(root), lib='numpy') for root in roots]
ax.scatter(roots, y_coord)
for i, x_coord in enumerate(roots):
  ax.annotate('X' + str(i + 1), xy = (x_coord, y_coord[i]), xycoords= ' data',
              xytext = (x_coord - 0.1, y_coord[i] + 0.3),  textcoords='data')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))
ax.plot(1, 0, '>k', transform=ax.get_yaxis_transform(), clip_on=False)
ax.plot(0, 1, '^k', transform=ax.get_xaxis_transform(), clip_on=False)
# Out:
# \text{Корни уравнения: }\left[ -0.815553418808961, \  1.42961182472556\right]

# %% [markdown]
# ### Задача 2.
# Решить уравнение $\sin^2(2x)=\ln x$ при $0< x \le 3$. Построить графики левой и правой части, отметить точку пересечения графиков.

# %%
def f(x, lib = 'sympy'):
  if lib == 'sympy':
    return (sympy.sin(2 * x)) ** 2
  if lib == 'numpy':
    return (np.sin(2 * x)) ** 2
  return 'Клоун, пиши нормально!'

def g(x, lib = 'sympy'):
  if lib == 'sympy':
    return sympy.ln(x)
  if lib == 'numpy':
    return np.log(x)
  return 'Клоун, пиши нормально!'

x = sympy.Symbol('x')
X = np.linspace(10**(-2), 3)

roots = [sympy.nsolve(sympy.Eq(f(x, lib='sympy'), g(x, lib='sympy')), x, x0) for x0 in [10**(-5), 2.7, 3.0]]
display(Latex(f'\\text{{Корни уравнения: }}{sympy.latex(roots)}'))

ax = plt.gca()
ax.plot(X, f(X, lib='numpy'), color='blue')
ax.plot(X, g(X, lib='numpy'), color='red')
y_coord = [f(float(root), lib='numpy') for root in roots]
ax.scatter(roots, y_coord)
for i, x_coord in enumerate(roots):
  ax.annotate('X' + str(i + 1), xy = (x_coord, y_coord[i]), xycoords= ' data',
              xytext = (x_coord - 0.1, y_coord[i] + 0.3),  textcoords='data')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))
ax.plot(1, 0, '>k', transform=ax.get_yaxis_transform(), clip_on=False)
ax.plot(0, 1, '^k', transform=ax.get_xaxis_transform(), clip_on=False)
# Out:
# \text{Корни уравнения: }\left[ 1.30133323382849, \  2.50217038800416, \  2.08594344788353\right]

# %% [markdown]
# ### Задача 3.
# Решить уравнение $\sin^2(2x^2-7x+6)=3/4$ на $[3, 4]$. Построить графики левой и правой части, отметить точки пересечения графиков.

# %%
def f(x, lib = 'sympy'):
  if lib == 'sympy':
    return (sympy.sin(2*x**2 - 7*x + 6)) ** 2
  if lib == 'numpy':
    return (np.sin(2*x**2 - 7*x + 6)) ** 2
  return 'Клоун, пиши нормально!'

def g(x):
  return 3/4 + 0 * x

x = sympy.Symbol('x')
X = np.linspace(3, 4)

roots = [sympy.nsolve(sympy.Eq(f(x, lib='sympy'), g(x)), x, x0) for x0 in [3, 3.1, 3.5, 3.7]]
display(Latex(f'\\text{{Корни уравнения: }}{sympy.latex(roots)}'))

ax = plt.gca()
ax.plot(X, f(X, lib='numpy'), color='blue')
ax.plot(X, g(X), color='red')
y_coord = [f(float(root), lib='numpy') for root in roots]
ax.scatter(roots, y_coord)
for i, x_coord in enumerate(roots):
  ax.annotate('X' + str(i + 1), xy = (x_coord, y_coord[i]), xycoords= ' data',
              xytext = (x_coord - 0.01, y_coord[i] + 0.03),  textcoords='data')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
# Out:
# \text{Корни уравнения: }\left[ 3.2186371581821, \  3.38722138942523, \  3.68072303274915, \  3.8118657096878\right]

# %% [markdown]
# ### Задача 4.
# Решить уравнение ${\rm tg}^4(2x^2+1)-10=0$ на интервале $[0, 0.2]$ методом дихотомии. График строить не нужно.

# %%
def f(x, lib='sympy'):
    if lib == 'sympy':
        return (sympy.tan(2*x**2 + 1)) ** 4 - 10
    if lib == 'numpy':
        return (np.tan(2*x**2 + 1)) ** 4 - 10
    return 'Клоун, пиши нормально!'

roots = [sympy.nsolve(sympy.Eq(f(x, lib='sympy'), 0), x, interval, verify=True) for interval in [[0, 0.1], [0.1, 0.2]]]
display(Latex(f'\\text{{Корни уравнения: }}{sympy.latex(roots)}'))
# Out:
# \text{Корни уравнения: }\left[ 0.171066377483446, \  0.171066377483446\right]

# %% [markdown]
# ### Задача 5.
# Решить систему уравнений
# $$
# \left\{\begin{matrix}
# (x - 1)^2 + (y - 2)^2 + (z + 3)^2 = 25\\
# x + y + z = 0\\
# -2x + 3y - z = 7
# \end{matrix}\right.
# $$
# начальное приближение (0, 0, 0).
# Проверить подстановкой.

# %%
x, y, z = sympy.symbols('x y z')

def f(x, y, z):
    return (x - 1)**2 + (y - 2)**2 + (z + 3)**2

def g(x, y, z):
    return x + y + z

def h(x, y, z):
    return -2*x + 3*y - z

root = sympy.nsolve((sympy.Eq(f(x, y, z), 25), sympy.Eq(g(x, y, z), 0), sympy.Eq(h(x, y, z), 7)), (x, y, z), (0, 0, 0))
display(Latex(f'\\text{{Корни уравнения: }}{sympy.latex(root)}'))

x0, y0, z0 = root
check = f(x0, y0, z0) == 25 and round(g(x0, y0, z0)) == 0 and h(x0, y0, z0) == 7
display(Latex(f'\\text{{Проверка: }}{sympy.latex(check)}'))
# Out:
# \text{Корни уравнения: }\left[\begin{matrix}-2.08606699924184\\1.22848325018954\\0.857583749052298\end{matrix}\right]
# \text{Проверка: }\text{True}

# %% [markdown]
# ### Индивидуальное задание
# Построить графики функций $f(x)$ и $g(x)$, уточнить координаты точек пересечения, решая численно соответствующее уравнение. На  графике отметить и подписать буквами $А_1$, $A_2$, ... точки пересечения графиков.

# %% [markdown]
# Вариант $121$
# \begin{align*}
#     f(x) = \frac{x^{2}}{2} && g(x) = - \frac{\left(x + 4\right) \left(5 x - 12\right)}{6}
# \end{align*}

# %%
def f(x):
    return x**2 / 2
def g(x):
    return -(x+4) * (5*x -12) / 6

X = np.linspace(-7, 7)
roots = [sympy.nsolve(sympy.Eq(f(x), g(x)), x, x0) for x0 in [-10, 10]]

ax = plt.gca()
ax.plot(X, f(X), label=r'f(x)', color='blue')
ax.plot(X, g(X), label=r'g(x)', color='red')
y_coord = [f(float(root)) for root in roots]
ax.scatter(roots, y_coord)
for i, x_coord in enumerate(roots):
    ax.annotate('A' + str(i + 1), xy=(x_coord, y_coord[i]), xycoords='data',
                xytext=(x_coord - 0.2, y_coord[i] + 2), textcoords='data')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))
ax.legend(loc='best')
